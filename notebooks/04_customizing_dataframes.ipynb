# %% [markdown]
# <img src="https://snipboard.io/Kx6OAi.jpg">
#
# # 4. Advanced Pandas: Customizing DataFrames
# <div style="margin-top: -20px;">Author:  David Yerrington</div>
#
# ## Learning Objectives
#
# - Understanding visual aspects of DataFrame output
# - Applying basic CSS properties to DataFrames
# - Using custom functions to style DataFrame
#
# ### Prerequisite Knowledge
# - Basic Pandas
#   - Difference between Series vs Dataframe
#   - Bitmasks, query function, selecting data
#   - Aggregations
#
# ## Environment Setup
#
# Don't forget to setup your Python environment from [the setup guide](../environment.md) if you haven't done so yet.

# %% [markdown]
# ### Imports

# %%
import pandas as pd, numpy as np

# %% [markdown]
# ### Dataset:  Yet, more Pokemon!

# %%
df = pd.read_csv("../data/pokemon.csv", encoding = "utf8")

# %% [markdown]
# # Styling DataFrames
#
# There are many reasons why you may want to change the styling of how a DataFrame is presented.  Just as plotting can help tell a story that numbers can't, tailoring your DataFrames to point out outliers, distinguish specific categories, or simply making your data easy to scan for publications is very practical.
#
# In this module, we will mostly be coding examples of the core constructs that support changing the default aesthetics of Pandas DataFrames.

# %% [markdown]
# ### Apply vs Applymap
# #### Apply
#
# As a refresher, `.apply()` can be used on `axis=0` (columns), or `axis=1` (rows).  The axis changes what is sent to the function supplied in `.apply()`.  If your DataFrame is 10(columns)x20(rows), `.apply([function])` is called once for each of the 10 columns when `axis = 0` (default) or for each of the 20 rows `axis = 1`.
#
# ![](https://snipboard.io/BRMnEI.jpg)
#
# #### Applymap
#
# Applymap is useful for working on and referencing all of your data in the context of each individual cell.  With `.apply()`, the input to your apply function per each call is either the length of your DataFrame (iteration by column series) or the length of your row (iteration by row).  With `.applymap()` the input is each single value of your DataFrame.  So if your DataFrame is 10x10, `applymap([function])` is called for each 100 items contained within it.
#
# ![](https://snipboard.io/e9QED3.jpg)

# %% [markdown]
# ### Question:  Without running the code example below, what do you think the result would be?
#
# ```python
# data = [
#    (1, 10, 100),
#    (2, 20, 200),
#    (3, 30, 300),
# ]
# test = pd.DataFrame(data)
# def my_function(val):
#     print(f"Hey I'm being called on {val}!")
#     return val + 1
# test.applymap(my_function)
# ```
#
# > If you're using an older version of Pandas the apply/applymap functions will be called twice on the first iteration because of a legacy optimization.  More recent version of Pandas don't behave this way.

# %%
test
# Out:
#    0   1    2
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300

# %%
# Now lets try it out here!
data = [
   (1, 10, 100),
   (2, 20, 200),
   (3, 30, 300),
]
test = pd.DataFrame(data)
def my_function(val):
    print(f"Hey I'm being called on {val}!")
    return val + 1
test.applymap(my_function)
# Out:
# Hey I'm being called on 1!
# Hey I'm being called on 2!
# Hey I'm being called on 3!
# Hey I'm being called on 10!
# Hey I'm being called on 20!
# Hey I'm being called on 30!
# Hey I'm being called on 100!
# Hey I'm being called on 200!
# Hey I'm being called on 300!
#    0   1    2
# 0  2  11  101
# 1  3  21  201
# 2  4  31  301

# %% [markdown]
# ### Working with Style
#
# Now that we know what which aspects of a DataFrame we can access with `.apply` and `.applymap`, we can customize many aspects of how DataFrames are displayed.
#
# Using the `df.style` object it's possible to access the "style" attribute that's attached to every single element displayed in the HTML of the DataFrame rendering in Jupyter.  When we use `.apply` and `.applymap` with `df.style`, the return of our functions used with these methods modifies the CSS "style" attribute of the post-rendered DataFrame HTML rather than the actual data.
#
# > What's been updated is the post-rendered HTML.  All DataFrames are specific HTML tags wrapped around each data element.

# %% [markdown]
# ### CSS in a Nutshell
#
# If we're going to change the CSS style properties of our post-rendered HTML, it may be useful to understand a few CSS properties.  First, CSS is a vast standard that allows web developers to control the look and feel of HTML documents (ie: a Document Object Model).
#
# It's impossible to become an expert in CSS without practice but the most useful CSS style properties to be know are:
#
#  - `color`:  Controls the text color [[ref](https://www.w3schools.com/cssref/pr_text_color.asp)]
#  - `font-family`: Change the font [[ref](https://www.w3schools.com/cssref/pr_font_font-family.asp)]
#  - `background-color`: Change an elements background color [[ref](https://www.w3schools.com/cssref/pr_font_font-family.asp)]
#
#  > Learn more about CSS @ [W3Schools](https://www.w3schools.com/cssref/)

# %% [markdown]
# ### Practicing CSS
#
# Jupyter allows us to render basic HTML tags right in a "markdown" type cell.  Lets explore these properties in more detail.
#
# #### Div with style = `color: red`
# HTML
# >```HTML
# ><div style = "color: red">This is text!</div>
# >```
#
# Output:
# ><div style = "color: red">This is text!</div>
#
#
# #### Div with style = `color: red; background-color: black;`
#
# HTML
# >```HTML
# ><div style = "color: red; background-color: black;">This is text!</div>
# >```
#
# Output:
# ><div style = "color: red; background-color: black;">This is text!</div>
#
#
# ## Question:  Can you search the web for the CSS style property make the font bold?
#
# Much of what we learn on the job at the lowest level is researched.  When thinking about how to change the aethetics of your DataFrame output, as long as we know the "style" HTML attribute is what is responsible for applying CSS properties, we only need to serach for them.
#
# ```HTML
# <div style="???">Am I bold text?</div>
# ```
#
# > Solution (double click this frame and edit below)
# > <div style="font-weight: bold;">Am I bold text?</div>

# %% [markdown]
# ### Applying styles properties to DataFrames
# Using `.applymap`, we will write a method that will change the text color of `Type 1` based on the Pokemon type using a dictionary whith keys that match the `Type 1` value and cooresponding colors for the given text.
#
# Also with `apply`, we can also use the `subset = [list of columns]` to tell apply which columns to apply to but at the same time showing other columns in context.
#
# > For a list of all CSS colors by name, check out: https://www.w3schools.com/cssref/css_colors.asp

# %%
type_map = dict(
    Fire    = "red",
    Grass   = "green",
    Water   = "blue",
    Bug     = "brown",
    Normal  = "emerald",
    Poison  = "darkgreen",
    Ghost   = "grey",
)

def style_type(val):
    # We will update this function
    color = type_map.get(val, "")
    return f"color: {color};"

df.head(10).style.applymap(style_type)
# Out:
# <style  type="text/css" >
# #T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col0,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col1,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col4,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col5,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col6,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col7,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col8,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col9,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col10,#T_e4293d16_5133_11eb_bddf_832d5af77e82row0_
0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >Bulbasaur</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >Grass</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >Poison</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >45</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >49</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col6" class="data row0 col6" >49</td>
#                         <td id="T_e4293d16_5133_11eb_bddf_832d5af77e82row0_col7" class="data row0 col7" >65</td>

# %% [markdown]
# ### Applying to the row `axis=1`
#
# Applying custom methods to the row axis is a little different than what we would expect from `.applymap()` because we're dealing with a series of multiple items rather than single values.  The return is expected to be a list of style properties matching the length of the input.
#
# For example, if we applied on row `axis = 1` with the subset `['Name', 'Type 1', 'Type 2']`, each row will have 3 elements.  The expected return is `["style for 'Name'", "Style for 'Type 1'", "Style for 'Type 3'"]`.
# > ![](https://snipboard.io/ruEj8l.jpg)

# %%
type_map = dict(
    Fire    = "red",
    Grass   = "green",
    Water   = "blue",
    Bug     = "brown",
    Normal  = "emerald",
    Poison  = "darkgreen",
    Ghost   = "grey",
)

def row_color(row):
    default = ""
    color = type_map.get(row['Type 1'], default)
    return [f"background-color: {color}; color: white;" for item in row]

df.head().style.apply(row_color, subset = ['Name', 'Type 1', 'Type 2'], axis = 1)
# Out:
# <style  type="text/css" >
# #T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col1,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col2,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col3,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col1,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col2,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col3,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col1,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col2,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col3,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col1,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col2,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col3{
#             background-color:  green;
#              color:  white;
#         }#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row4_col1,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row4_col2,#T_8ce4b05c_5134_11eb_bddf_832d5af77e82row4_col3{
#             background-color:  red;
#              color:  white;
#         }</style><table id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >#</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Type 1</th>        <th class="col_heading level0 col3" >Type 2</th>        <th class="col_heading level0 col4" >HP</th>        <th class="col_heading level0 col5" >Attack</th>        <th class="col_heading level0 col6" >Defense</th>        <th class="col_heading level0 col7" >Sp. Atk</th>        <th class="col_heading level0 col8" >Sp. Def</th>        <th class="col_heading level0 col9" >Speed</th>        <th class="col_heading level0 col10" >Generation</th>        <th class="col_heading level0 col11" >Legendary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >Bulbasaur</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >Grass</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >Poison</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >45</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >49</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col6" class="data row0 col6" >49</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col7" class="data row0 col7" >65</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col8" class="data row0 col8" >65</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col9" class="data row0 col9" >45</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col10" class="data row0 col10" >1</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row0_col11" class="data row0 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col1" class="data row1 col1" >Ivysaur</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col2" class="data row1 col2" >Grass</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col3" class="data row1 col3" >Poison</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col4" class="data row1 col4" >60</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col5" class="data row1 col5" >62</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col6" class="data row1 col6" >63</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col7" class="data row1 col7" >80</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col8" class="data row1 col8" >80</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col9" class="data row1 col9" >60</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row1_col11" class="data row1 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col1" class="data row2 col1" >Venusaur</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col2" class="data row2 col2" >Grass</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col3" class="data row2 col3" >Poison</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col4" class="data row2 col4" >80</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col5" class="data row2 col5" >82</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col6" class="data row2 col6" >83</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col7" class="data row2 col7" >100</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col8" class="data row2 col8" >100</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col9" class="data row2 col9" >80</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col10" class="data row2 col10" >1</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row2_col11" class="data row2 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col1" class="data row3 col1" >Mega Venusaur</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col2" class="data row3 col2" >Grass</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col3" class="data row3 col3" >Poison</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col4" class="data row3 col4" >80</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col5" class="data row3 col5" >100</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col6" class="data row3 col6" >123</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col7" class="data row3 col7" >122</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col8" class="data row3 col8" >120</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col9" class="data row3 col9" >80</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col10" class="data row3 col10" >1</td>
#                         <td id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82row3_col11" class="data row3 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8ce4b05c_5134_11eb_bddf_832d5af77e82level0_row4" class="row_heading level0 row4" >4<

# %% [markdown]
# ### Question:  How would we also change the background of "Legendary" to "yellow" if the value == `False`?

# %%
df.tail().style.apply(row_color, subset = ['Name', 'Type 1', 'Type 2'], axis = 1).applymap(lambda val: "color: yellow" if val == True else "color: red", subset="Legendary")
# Out:
# <style  type="text/css" >
# #T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col1,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col2,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col3,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col1,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col2,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col3,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_col1,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_col2,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_col3,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row3_col1,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row3_col2,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row3_col3{
#             background-color:  ;
#              color:  white;
#         }#T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col11,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col11,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_col11,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row3_col11,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row4_col11{
#             color:  yellow;
#         }#T_2bb8f206_5135_11eb_bddf_832d5af77e82row4_col1,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row4_col2,#T_2bb8f206_5135_11eb_bddf_832d5af77e82row4_col3{
#             background-color:  red;
#              color:  white;
#         }</style><table id="T_2bb8f206_5135_11eb_bddf_832d5af77e82" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >#</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Type 1</th>        <th class="col_heading level0 col3" >Type 2</th>        <th class="col_heading level0 col4" >HP</th>        <th class="col_heading level0 col5" >Attack</th>        <th class="col_heading level0 col6" >Defense</th>        <th class="col_heading level0 col7" >Sp. Atk</th>        <th class="col_heading level0 col8" >Sp. Def</th>        <th class="col_heading level0 col9" >Speed</th>        <th class="col_heading level0 col10" >Generation</th>        <th class="col_heading level0 col11" >Legendary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2bb8f206_5135_11eb_bddf_832d5af77e82level0_row0" class="row_heading level0 row0" >795</th>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >796</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >Diancie</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >Rock</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >Fairy</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >50</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >100</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col6" class="data row0 col6" >150</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col7" class="data row0 col7" >100</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col8" class="data row0 col8" >150</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col9" class="data row0 col9" >50</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col10" class="data row0 col10" >6</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row0_col11" class="data row0 col11" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_2bb8f206_5135_11eb_bddf_832d5af77e82level0_row1" class="row_heading level0 row1" >796</th>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col0" class="data row1 col0" >797</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col1" class="data row1 col1" >Mega Diancie</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col2" class="data row1 col2" >Rock</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col3" class="data row1 col3" >Fairy</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col4" class="data row1 col4" >50</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col5" class="data row1 col5" >160</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col6" class="data row1 col6" >110</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col7" class="data row1 col7" >160</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col8" class="data row1 col8" >110</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col9" class="data row1 col9" >110</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col10" class="data row1 col10" >6</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row1_col11" class="data row1 col11" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_2bb8f206_5135_11eb_bddf_832d5af77e82level0_row2" class="row_heading level0 row2" >797</th>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_col0" class="data row2 col0" >798</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_col1" class="data row2 col1" >Hoopa Confined</td>
#                         <td id="T_2bb8f206_5135_11eb_bddf_832d5af77e82row2_
th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Type 1</th>        <th class="col_heading level0 col3" >Type 2</th>        <th class="col_heading level0 col4" >HP</th>        <th class="col_heading level0 col5" >Attack</th>        <th class="col_heading level0 col6" >Defense</th>        <th class="col_heading level0 col7" >Sp. Atk</th>        <th class="col_heading level0 col8" >Sp. Def</th>        <th class="col_heading level0 col9" >Speed</th>        <th class="col_heading level0 col10" >Generation</th>        <th class="col_heading level0 col11" >Legendary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_92914334_5135_11eb_bddf_832d5af77e82level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >Bulbasaur</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >Grass</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >Poison</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >45</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >49</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col6" class="data row0 col6" >49</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col7" class="data row0 col7" >65</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col8" class="data row0 col8" >65</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col9" class="data row0 col9" >45</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col10" class="data row0 col10" >1</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row0_col11" class="data row0 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_92914334_5135_11eb_bddf_832d5af77e82level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col1" class="data row1 col1" >Ivysaur</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col2" class="data row1 col2" >Grass</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col3" class="data row1 col3" >Poison</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col4" class="data row1 col4" >60</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col5" class="data row1 col5" >62</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col6" class="data row1 col6" >63</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col7" class="data row1 col7" >80</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col8" class="data row1 col8" >80</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col9" class="data row1 col9" >60</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row1_col11" class="data row1 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_92914334_5135_11eb_bddf_832d5af77e82level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row2_col1" class="data row2 col1" >Venusaur</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row2_col2" class="data row2 col2" >Grass</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row2_col3" class="data row2 col3" >Poison</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82row2_col4" class="data row2 col4" >80</td>
#                         <td id="T_92914334_5135_11eb_bddf_832d5af77e82

# %% [markdown]
# #### Inline `.bar` Charts
#
# > Pandas bar docs: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.formats.style.Styler.bar.html

# %%
df.head(15).style \
    .bar(subset = ['HP']) \
    .bar(subset = ['Attack'], color = "lightblue") \
    .bar(subset = ['Defense'], color = "pink")
# Out:
# <style  type="text/css" >
# #T_eb42edca_5135_11eb_bddf_832d5af77e82row0_col4,#T_eb42edca_5135_11eb_bddf_832d5af77e82row13_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.6%, transparent 14.6%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 26.4%, transparent 26.4%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 15.9%, transparent 15.9%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.2%, transparent 51.2%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.2%, transparent 38.2%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 31.8%, transparent 31.8%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row2_col4,#T_eb42edca_5135_11eb_bddf_832d5af77e82row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 56.4%, transparent 56.4%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 54.5%, transparent 54.5%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 72.7%, transparent 72.7%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 100.0%, transparent 100.0%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row4_col4,#T_eb42edca_5135_11eb_bddf_832d5af77e82row13_col6,#T_eb42edca_5135_11eb_bddf_832d5af77e82row14_col5{
#             width:  10em;
#              height:  80%;
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 29.1%, transparent 29.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 9.1%, transparent 9.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.3%, transparent 46.3%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 40.0%, transparent 40.0%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 26.1%, transparent 26.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row6_col4,#T_eb42edca_5135_11eb_bddf_832d5af77e82row7_col4,#T_eb42edca_5135_11eb_bddf_832d5af77e82row8_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 58.2%, transparent 58.2%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row6_col6,#T_eb42edca_5135_11eb_bddf_832d5af77e82row8_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 48.9%, transparent 48.9%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row7_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row7_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 86.4%, transparent 86.4%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row8_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 76.4%, transparent 76.4%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row9_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.2%, transparent 12.2%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row9_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 25.5%, transparent 25.5%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row9_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 34.1%, transparent 34.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row10_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.8%, transparent 48.8%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row10_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 39.1%, transparent 39.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row10_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 51.1%, transparent 51.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row11_col4,#T_eb42edca_5135_11eb_bddf_832d5af77e82row12_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.6%, transparent 97.6%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row11_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 57.3%, transparent 57.3%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row11_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 73.9%, transparent 73.9%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row12_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 75.5%, transparent 75.5%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row12_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 96.6%, transparent 96.6%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row13_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 9.1%, transparent 9.1%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row14_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.8%, transparent 26.8%);
#         }#T_eb42edca_5135_11eb_bddf_832d5af77e82row14_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,pink 22.7%, transparent 22.7%);
#         }</style><table id="T_eb42edca_5135_11eb_bddf_832d5af77e82" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >#</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Type 1</th>        <th class="col_heading level0 col3" >Type 2</th>        <th class="col_heading level0 col4" >HP</th>        <th class="col_heading level0 col5" >Attack</th>        <th class="col_heading level0 col

# %% [markdown]
# ### Adding Captions with `.set_caption("your caption!")`
#
# Sometimes you will take a screenshot of a sample of data in a DataFrame.  It's helpful to add a caption to it so it so you don't have to add one later in post production.

# %%
columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
# Code below
df[columns].corr().style.background_gradient().set_caption('This is a corr chart')
# Out:
# <style  type="text/css" >
# #T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col0,#T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col1,#T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col2,#T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col3,#T_18e06e88_5136_11eb_bddf_832d5af77e82row4_col4,#T_18e06e88_5136_11eb_bddf_832d5af77e82row5_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col1{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col2{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col3{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col4,#T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col5{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col0{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col2{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col3{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col4{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col5{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col0{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col1{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col3,#T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col5,#T_18e06e88_5136_11eb_bddf_832d5af77e82row4_col1,#T_18e06e88_5136_11eb_bddf_832d5af77e82row5_col0,#T_18e06e88_5136_11eb_bddf_832d5af77e82row5_col2,#T_18e06e88_5136_11eb_bddf_832d5af77e82row5_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col4{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col0{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col1{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col2{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col4{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col5{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row4_col0{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row4_col2{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row4_col3{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row4_col5{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row5_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_18e06e88_5136_11eb_bddf_832d5af77e82row5_col3{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }</style><table id="T_18e06e88_5136_11eb_bddf_832d5af77e82" ><caption>This is a corr chart</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >Attack</th>        <th class="col_heading level0 col2" >Defense</th>        <th class="col_heading level0 col3" >Sp. Atk</th>        <th class="col_heading level0 col4" >Sp. Def</th>        <th class="col_heading level0 col5" >Speed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18e06e88_5136_11eb_bddf_832d5af77e82level0_row0" class="row_heading level0 row0" >HP</th>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >0.422386</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >0.239622</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >0.362380</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >0.378718</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >0.175952</td>
#             </tr>
#             <tr>
#                         <th id="T_18e06e88_5136_11eb_bddf_832d5af77e82level0_row1" class="row_heading level0 row1" >Attack</th>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col0" class="data row1 col0" >0.422386</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col2" class="data row1 col2" >0.438687</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col3" class="data row1 col3" >0.396362</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col4" class="data row1 col4" >0.263990</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row1_col5" class="data row1 col5" >0.381240</td>
#             </tr>
#             <tr>
#                         <th id="T_18e06e88_5136_11eb_bddf_832d5af77e82level0_row2" class="row_heading level0 row2" >Defense</th>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col0" class="data row2 col0" >0.239622</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col1" class="data row2 col1" >0.438687</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col3" class="data row2 col3" >0.223549</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col4" class="data row2 col4" >0.510747</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row2_col5" class="data row2 col5" >0.015227</td>
#             </tr>
#             <tr>
#                         <th id="T_18e06e88_5136_11eb_bddf_832d5af77e82level0_row3" class="row_heading level0 row3" >Sp. Atk</th>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col0" class="data row3 col0" >0.362380</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col1" class="data row3 col1" >0.396362</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col2" class="data row3 col2" >0.223549</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col4" class="data row3 col4" >0.506121</td>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77e82row3_col5" class="data row3 col5" >0.473018</td>
#             </tr>
#             <tr>
#                         <th id="T_18e06e88_5136_11eb_bddf_832d5af77e82level0_row4" class="row_heading level0 row4" >Sp. Def</th>
#                         <td id="T_18e06e88_5136_11eb_bddf_832d5af77

# %% [markdown]
# ### Highlighting the min or max

# %%
columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
# Code below
df[columns].head(10).style.highlight_max(color = "red").highlight_min(color = "lightblue")
# Out:
# <style  type="text/css" >
# #T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col0,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col0,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col2,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col4,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col5,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col1,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col5,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row8_col3,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row8_col5{
#             background-color:  red;
#         }#T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col0,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col2,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col4,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row9_col1,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row9_col3,#T_3d96c07e_5136_11eb_bddf_832d5af77e82row9_col5{
#             background-color:  lightblue;
#         }</style><table id="T_3d96c07e_5136_11eb_bddf_832d5af77e82" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >Attack</th>        <th class="col_heading level0 col2" >Defense</th>        <th class="col_heading level0 col3" >Sp. Atk</th>        <th class="col_heading level0 col4" >Sp. Def</th>        <th class="col_heading level0 col5" >Speed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >45</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >49</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >49</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >65</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >65</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row1_col0" class="data row1 col0" >60</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row1_col1" class="data row1 col1" >62</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row1_col2" class="data row1 col2" >63</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row1_col3" class="data row1 col3" >80</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row1_col4" class="data row1 col4" >80</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row1_col5" class="data row1 col5" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col0" class="data row2 col0" >80</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col1" class="data row2 col1" >82</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col2" class="data row2 col2" >83</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col3" class="data row2 col3" >100</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col4" class="data row2 col4" >100</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row2_col5" class="data row2 col5" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col0" class="data row3 col0" >80</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col1" class="data row3 col1" >100</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col2" class="data row3 col2" >123</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col3" class="data row3 col3" >122</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col4" class="data row3 col4" >120</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row3_col5" class="data row3 col5" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col0" class="data row4 col0" >39</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col1" class="data row4 col1" >52</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col2" class="data row4 col2" >43</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col3" class="data row4 col3" >60</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col4" class="data row4 col4" >50</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row4_col5" class="data row4 col5" >65</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row5_col0" class="data row5 col0" >58</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row5_col1" class="data row5 col1" >64</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row5_col2" class="data row5 col2" >58</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row5_col3" class="data row5 col3" >80</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row5_col4" class="data row5 col4" >65</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row5_col5" class="data row5 col5" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col0" class="data row6 col0" >78</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col1" class="data row6 col1" >84</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col2" class="data row6 col2" >78</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col3" class="data row6 col3" >109</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col4" class="data row6 col4" >85</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row6_col5" class="data row6 col5" >100</td>
#             </tr>
#             <tr>
#                         <th id="T_3d96c07e_5136_11eb_bddf_832d5af77e82level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col0" class="data row7 col0" >78</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col1" class="data row7 col1" >130</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col2" class="data row7 col2" >111</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col3" class="data row7 col3" >130</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col4" class="data row7 col4" >85</td>
#                         <td id="T_3d96c07e_5136_11eb_bddf_832d5af77e82row7_col5" class="data row

# %% [markdown]
# ### Question:  What appears to be happening here?  Why do you think we see multiple elements highlighted?

# %% [markdown]
# ### Lastly, using `.format()`
#
# Format behaves like `.applymap()` but you can configure which columns map to specific methods.  Useful for applying money format to values, changing case of text, changing format of data.

# %%
df.head(10).style.format({
    "Name": lambda val: val.upper(),
    "Type 1": lambda val: val.lower(),
    "HP": "${:20,.2f}"
})
# Out:
# <style  type="text/css" >
# </style><table id="T_4fe440e4_5136_11eb_bddf_832d5af77e82" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >#</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Type 1</th>        <th class="col_heading level0 col3" >Type 2</th>        <th class="col_heading level0 col4" >HP</th>        <th class="col_heading level0 col5" >Attack</th>        <th class="col_heading level0 col6" >Defense</th>        <th class="col_heading level0 col7" >Sp. Atk</th>        <th class="col_heading level0 col8" >Sp. Def</th>        <th class="col_heading level0 col9" >Speed</th>        <th class="col_heading level0 col10" >Generation</th>        <th class="col_heading level0 col11" >Legendary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fe440e4_5136_11eb_bddf_832d5af77e82level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col1" class="data row0 col1" >BULBASAUR</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col2" class="data row0 col2" >grass</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col3" class="data row0 col3" >Poison</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col4" class="data row0 col4" >$               45.00</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col5" class="data row0 col5" >49</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col6" class="data row0 col6" >49</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col7" class="data row0 col7" >65</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col8" class="data row0 col8" >65</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col9" class="data row0 col9" >45</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col10" class="data row0 col10" >1</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row0_col11" class="data row0 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4fe440e4_5136_11eb_bddf_832d5af77e82level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col1" class="data row1 col1" >IVYSAUR</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col2" class="data row1 col2" >grass</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col3" class="data row1 col3" >Poison</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col4" class="data row1 col4" >$               60.00</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col5" class="data row1 col5" >62</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col6" class="data row1 col6" >63</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col7" class="data row1 col7" >80</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col8" class="data row1 col8" >80</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col9" class="data row1 col9" >60</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row1_col11" class="data row1 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4fe440e4_5136_11eb_bddf_832d5af77e82level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col1" class="data row2 col1" >VENUSAUR</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col2" class="data row2 col2" >grass</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col3" class="data row2 col3" >Poison</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col4" class="data row2 col4" >$               80.00</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col5" class="data row2 col5" >82</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col6" class="data row2 col6" >83</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col7" class="data row2 col7" >100</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col8" class="data row2 col8" >100</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col9" class="data row2 col9" >80</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col10" class="data row2 col10" >1</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row2_col11" class="data row2 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4fe440e4_5136_11eb_bddf_832d5af77e82level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col1" class="data row3 col1" >MEGA VENUSAUR</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col2" class="data row3 col2" >grass</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col3" class="data row3 col3" >Poison</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col4" class="data row3 col4" >$               80.00</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col5" class="data row3 col5" >100</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col6" class="data row3 col6" >123</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col7" class="data row3 col7" >122</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col8" class="data row3 col8" >120</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col9" class="data row3 col9" >80</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col10" class="data row3 col10" >1</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row3_col11" class="data row3 col11" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4fe440e4_5136_11eb_bddf_832d5af77e82level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col1" class="data row4 col1" >CHARMANDER</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col2" class="data row4 col2" >fire</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col4" class="data row4 col4" >$               39.00</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col5" class="data row4 col5" >52</td>
#                         <td id="T_4fe440e4_5136_11eb_bddf_832d5af77e82row4_col6" class="data row4

# %% [markdown]
# ## Summary
#
# - `df.style` is a way we access DataFrame "style" attributes as they are rendered as HTML.
# - CSS is a standard that defines how HTML element can be styled visually (and other important HTML aspects).
# - `df.style.applymap(func)` styles individual cells.
# >Expects a `style` string as the return to your function.
# - `df.style.apply(func, axis=0)` styles row cells.
# > Expects a series of `style` strings as the return to your function.
#
# - Built-in style methods
#   - `.background_gradient` - Changes background based on matplotlibs color map (`cmap`) like a heatmap.
#   - `.bar` - Draws bars as the backround representing the displayed values in a column series.
#   - `.set_caption` - Adds a caption to the top of your DataFrame useful for taking screenshots.
#   - `.highlight_min` - Highlights the minimum value of each column in a subset.
#   - `.highlight_max` - Highlights the maximum value of each columns in a subset.
#   - `.format` - Flexible mapping method that matches column keys to specific functions that operate like `.applymap()`
